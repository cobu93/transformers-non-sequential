# %%
import sys
sys.path.append('../Utils')
sys.setrecursionlimit(10000)

import joblib
import pandas as pd
from sklearn import pipeline, preprocessing, metrics, model_selection, decomposition, cluster, compose
from scipy import stats
import numpy as np

import math

import matplotlib.pyplot as plt

# %matplotlib inline

from utils import ReorderTransformer, LabelingTransformer, ClusterMultitree, AttentionTransformer

import sys
import os
import torch

import joblib

SEED = 42

# %%
DATASET_DIR = '../Dataset'
MODEL_DIR = '../Models/cluster_multitree'

# %% [markdown]
# ## Dataset

# %%
train_df = pd.read_csv(os.path.join(DATASET_DIR, 'n_train.csv'))
dev_df = pd.read_csv(os.path.join(DATASET_DIR, 'n_dev.csv'))

# %%
train_X, train_y = joblib.load(os.path.join(DATASET_DIR, 'attn_train.jl'))
dev_X, dev_y = joblib.load(os.path.join(DATASET_DIR, 'attn_dev.jl'))

# %%
X = np.concatenate((train_X, dev_X))
y = np.concatenate((train_y, dev_y))

# %%
df = pd.concat((train_df, dev_df))

# %%
train_indices = np.arange(0, train_X.shape[0])
dev_indices = np.arange(train_X.shape[0], train_X.shape[0] + dev_X.shape[0])

# %%
ds_info = joblib.load(os.path.join(DATASET_DIR, 'ds_info.jl'))

columns = ds_info['columns']
numerical_cols = ds_info['numerical_columns']
categorical_cols = ds_info['categorical_columns']
label_col = ds_info['target_column']

# %%
X = X.reshape(-1, (len(columns) - 1) ** 2)

# %% [markdown]
# ## Grid search on number of clusters

# %% [markdown]
# ### Visualization

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(X[train_indices])
X_pca = pca.transform(X)

# %%
X_pca.shape
# Out:
# (41188, 2)

# %%
test_range = [i for i in range(2, 11)]

total_tests = len(test_range)
cols = 3
rows = math.ceil(total_tests / 3)


fig, axes = plt.subplots(rows, cols, figsize=(15, 8))

for row in range(rows):
    for col in range(cols):
        ax = axes[row, col]
        
        test_index = row * cols + col
        
        if test_index < len(test_range):
            n_clusters = test_range[test_index]

            kmeans = cluster.KMeans(n_clusters=n_clusters, random_state=SEED)
            kmeans.fit(X[train_indices])
            y_clust = kmeans.predict(X[train_indices])

            ax.scatter(X_pca[train_indices, 0], X_pca[train_indices, 1], c=y_clust)
            ax.set_title('{} clusters'.format(n_clusters))
            
            ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

fig.tight_layout()
fig.savefig('Attention clustering.png')
plt.show()

# %% [markdown]
# ### Processing original data

# %%
transformer = joblib.load('../Models/transformer_v3/transformer_v3_baseline.jl')

# %%
inp = transformer['preprocessing'].transform(train_df.drop(label_col, axis=1))

# %%
transformer['classifier'].module_
# Out:
# TransformerModelv3(
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=32, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=32, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (cat_embedding): Embedding(53, 16)
#   (num_embedding): ModuleList(
#     (0): Linear(in_features=1, out_features=16, bias=True)
#     (1): Linear(in_features=1, out_features=16, bias=True)
#     (2): Linear(in_features=1, out_features=16, bias=True)
#     (3): Linear(in_features=1, out_features=16, bias=True)
#     (4): Linear(in_features=1, out_features=16, bias=True)
#     (5): Linear(in_features=1, out_features=16, bias=True)
#     (6): Linear(in_features=1, out_features=16, bias=True)
#     (7): Linear(in_features=1, out_features=16, bias=True)
#     (8): Linear(in_features=1, out_features=16, bias=True)
#   )
#   (decoder): Linear(in_features=304, out_features=1, bias=True)
#   (activation): Sigmoid()
# )

# %%
categorical_transformer = pipeline.Pipeline(steps=[
        ('label', LabelingTransformer())])

numerical_transformer = pipeline.Pipeline(steps=[
        ('scaler', preprocessing.MinMaxScaler())
])

preprocessing_pipe = pipeline.Pipeline([
    ('reordering', ReorderTransformer(categorical_columns=categorical_cols, numerical_columns=numerical_cols)),
    ('columns_transformer', compose.ColumnTransformer(
        remainder='drop', 
        transformers=[
            ('categorical_transformer', categorical_transformer , categorical_cols),
            ('numerical_transformer', numerical_transformer , numerical_cols)
        ])
    )
])


pipe = pipeline.Pipeline([
    ('feature_concat', pipeline.FeatureUnion([
        ('original_data_preprocessing', preprocessing_pipe), 
        ('attention_extraction', AttentionTransformer('../Models/transformer_v3/transformer_v3_baseline.jl'))        
    ])),
    ('classifier', ClusterMultitree(n_features=len(columns) - 1, random_state=SEED))
])

# %%
param_grid = {
    'classifier__n_clusters': [x for x in range(2, 10, 2)],#[2 ** x for x in range(1, 11)],
    'classifier__max_depth': [x for x in range(1, 15)]
}

clf = model_selection.GridSearchCV(
    pipe,
    param_grid, 
    cv=((train_indices, dev_indices),),
    scoring='accuracy',
    refit=False,
    verbose=3,
)

clf = clf.fit(df.drop(label_col, axis=1), df[label_col])
# Out:
# Fitting 1 folds for each of 56 candidates, totalling 56 fits
# [CV 1/1] END classifier__max_depth=1, classifier__n_clusters=2; total time=   8.4s
# [CV 1/1] END classifier__max_depth=1, classifier__n_clusters=4; total time=  10.7s
# [CV 1/1] END classifier__max_depth=1, classifier__n_clusters=6; total time=   7.4s
# [CV 1/1] END classifier__max_depth=1, classifier__n_clusters=8; total time=   8.0s
# [CV 1/1] END classifier__max_depth=2, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=2, classifier__n_clusters=4; total time=   5.8s
# [CV 1/1] END classifier__max_depth=2, classifier__n_clusters=6; total time=   6.8s
# [CV 1/1] END classifier__max_depth=2, classifier__n_clusters=8; total time=   7.8s
# [CV 1/1] END classifier__max_depth=3, classifier__n_clusters=2; total time=   4.4s
# [CV 1/1] END classifier__max_depth=3, classifier__n_clusters=4; total time=   5.8s
# [CV 1/1] END classifier__max_depth=3, classifier__n_clusters=6; total time=   7.1s
# [CV 1/1] END classifier__max_depth=3, classifier__n_clusters=8; total time=   7.9s
# [CV 1/1] END classifier__max_depth=4, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=4, classifier__n_clusters=4; total time=   5.8s
# [CV 1/1] END classifier__max_depth=4, classifier__n_clusters=6; total time=   7.1s
# [CV 1/1] END classifier__max_depth=4, classifier__n_clusters=8; total time=   8.0s
# [CV 1/1] END classifier__max_depth=5, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=5, classifier__n_clusters=4; total time=   5.9s
# [CV 1/1] END classifier__max_depth=5, classifier__n_clusters=6; total time=   6.8s
# [CV 1/1] END classifier__max_depth=5, classifier__n_clusters=8; total time=   7.7s
# [CV 1/1] END classifier__max_depth=6, classifier__n_clusters=2; total time=   4.5s
# [CV 1/1] END classifier__max_depth=6, classifier__n_clusters=4; total time=   6.0s
# [CV 1/1] END classifier__max_depth=6, classifier__n_clusters=6; total time=   7.0s
# [CV 1/1] END classifier__max_depth=6, classifier__n_clusters=8; total time=   7.8s
# [CV 1/1] END classifier__max_depth=7, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=7, classifier__n_clusters=4; total time=   6.1s
# [CV 1/1] END classifier__max_depth=7, classifier__n_clusters=6; total time=   7.0s
# [CV 1/1] END classifier__max_depth=7, classifier__n_clusters=8; total time=   7.7s
# [CV 1/1] END classifier__max_depth=8, classifier__n_clusters=2; total time=   4.5s
# [CV 1/1] END classifier__max_depth=8, classifier__n_clusters=4; total time=   6.0s
# [CV 1/1] END classifier__max_depth=8, classifier__n_clusters=6; total time=   7.0s
# [CV 1/1] END classifier__max_depth=8, classifier__n_clusters=8; total time=   7.9s
# [CV 1/1] END classifier__max_depth=9, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=9, classifier__n_clusters=4; total time=   6.1s
# [CV 1/1] END classifier__max_depth=9, classifier__n_clusters=6; total time=   6.8s
# [CV 1/1] END classifier__max_depth=9, classifier__n_clusters=8; total time=   7.9s
# [CV 1/1] END classifier__max_depth=10, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=10, classifier__n_clusters=4; total time=   5.9s
# [CV 1/1] END classifier__max_depth=10, classifier__n_clusters=6; total time=   6.9s
# [CV 1/1] END classifier__max_depth=10, classifier__n_clusters=8; total time=   7.9s
# [CV 1/1] END classifier__max_depth=11, classifier__n_clusters=2; total time=   4.5s
# [CV 1/1] END classifier__max_depth=11, classifier__n_clusters=4; total time=   5.8s
# [CV 1/1] END classifier__max_depth=11, classifier__n_clusters=6; total time=   6.8s
# [CV 1/1] END classifier__max_depth=11, classifier__n_clusters=8; total time=   8.0s
# [CV 1/1] END classifier__max_depth=12, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=12, classifier__n_clusters=4; total time=   6.0s
# [CV 1/1] END classifier__max_depth=12, classifier__n_clusters=6; total time=   6.8s
# [CV 1/1] END classifier__max_depth=12, classifier__n_clusters=8; total time=   8.0s
# [CV 1/1] END classifier__max_depth=13, classifier__n_clusters=2; total time=   4.7s
# [CV 1/1] END classifier__max_depth=13, classifier__n_clusters=4; total time=   5.9s
# [CV 1/1] END classifier__max_depth=13, classifier__n_clusters=6; total time=   6.9s
# [CV 1/1] END classifier__max_depth=13, classifier__n_clusters=8; total time=   8.0s
# [CV 1/1] END classifier__max_depth=14, classifier__n_clusters=2; total time=   4.6s
# [CV 1/1] END classifier__max_depth=14, classifier__n_clusters=4; total time=   5.8s
# [CV 1/1] END classifier__max_depth=14, classifier__n_clusters=6; total time=   6.9s
# [CV 1/1] END classifier__max_depth=14, classifier__n_clusters=8; total time=   7.8s

# %%
clf.best_params_
# Out:
# {'classifier__max_depth': 3, 'classifier__n_clusters': 6}

# %%
pipe.set_params(**clf.best_params_)
_ = pipe.fit(train_df.drop(label_col, axis=1), train_df[label_col])

# %%
pipe.score(train_df.drop(label_col, axis=1), train_df[label_col])
# Out:
# 0.9015143141372831

# %%
pipe.score(dev_df.drop(label_col, axis=1), dev_df[label_col])
# Out:
# 0.9032

# %%
joblib.dump(pipe, os.path.join(MODEL_DIR, 'cluster_multitree_baseline.jl'))
# Out:
# ['../Models/cluster_multitree/cluster_multitree_baseline.jl']
