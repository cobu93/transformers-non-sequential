# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from tqdm.notebook import tqdm
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, accuracy_score
import scipy
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline


torch.manual_seed(42)

# %%
train_df = pd.read_csv('n_train.csv')
dev_df = pd.read_csv('n_dev.csv')

# %% [markdown]
# ## Preprocessing data

# %%
train_size = train_df.shape[0]
dev_size = dev_df.shape[0]

# %%
train_size, dev_size
# Out:
# (429, 185)

# %%
df = pd.concat([train_df, dev_df])

# %%
categorical_cols = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Credit_History', 'Property_Area']
numerical_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']
label_col = 'Loan_Status'

# %%
embedding_idx_data = {'Gender': {'Male': 0, 'Female': 1},
                'Married': {'No': 2, 'Yes': 3},
                'Dependents': {'0': 4, '1': 5, '2': 6, '3+': 7 },
                'Education': {'Graduate': 8, 'Not Graduate': 9},
                'Self_Employed': {'No': 10, 'Yes': 11},
                'Credit_History': {0: 12, 1: 13},
                'Property_Area': {'Urban': 14, 'Rural': 15, 'Semiurban': 16}
               }

# %%
df = df.replace(embedding_idx_data)

# %%
df[label_col] = df[label_col].replace({-1: 0})

# %%
# One hot encoding 
df = df[categorical_cols + numerical_cols + [label_col]]

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       0        3           6          8             10            13.0
# 1       0        2           4          8             10            13.0
# 2       0        3           7          9             10            12.0
# 3       0        3           4          9             10            13.0
# 4       0        3           4          8             10            13.0
#
#    Property_Area  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             14           2500.0             1840.0       109.0
# 1             16           5941.0             4232.0       296.0
# 2             16           4931.0                0.0       128.0
# 3             15           2894.0             2792.0       155.0
# 4             14           2500.0             3796.0       120.0
#
#    Loan_Amount_Term  Loan_Status
# 0             360.0          1.0
# 1             360.0          1.0
# ...

# %%
train_df = df.iloc[:train_size]
dev_df = df.iloc[train_size:]

assert train_df.shape[0] == train_size
assert dev_df.shape[0] == dev_size

# %%
min_max_scaler = preprocessing.MinMaxScaler()
min_max_scaler.fit(train_df[numerical_cols])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
train_df[numerical_cols] = min_max_scaler.transform(train_df[numerical_cols])
dev_df[numerical_cols] = min_max_scaler.transform(dev_df[numerical_cols])
# Out:
# /home/uriel/miniconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/uriel/miniconda3/envs/ML/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/uriel/miniconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# ...

# %%
X_train = train_df.drop(label_col, axis=1).values
y_train = train_df[label_col].values


X_dev = dev_df.drop(label_col, axis=1).values
y_dev = dev_df[label_col].values

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_dev = np.expand_dims(X_dev, axis=-1)

# %% [markdown]
# ## Model

# %%
print('Examples:{}    Features:{}'.format(X_train.shape[0], X_train.shape[1]))
# Out:
# Examples:429    Features:11

# %%
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
                
        encoder_layers = nn.TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, nlayers)
        self.embedding = nn.Embedding(ntoken, ninp)
        
        self.num_embedding = nn.Linear(1, ninp)
        
        self.decoder = nn.Linear(440, 1)
        
        self.activation = nn.Sigmoid()
        
    
    def forward(self, src):
        src_cat = self.embedding(src[:, :len(categorical_cols)].squeeze().long())
        src_num = self.num_embedding(src[:, len(categorical_cols):])
        src = torch.cat((src_cat, src_num), 1)
        src = src.transpose(0, 1)
        
        output = self.transformer_encoder(src).transpose(0, 1)
        output = torch.flatten(output, start_dim=1)
        output = self.decoder(output)
        output = self.activation(output)
        
        return output

# %%
model = TransformerModel(
    42, # The size of vocabulary
    40, # Embedding size 
    4, # The number of heads in the multiheadattention models 
    64, # The dimension of the feedforward network model in nn.TransformerEncoder
    1, # The number of nn.TransformerEncoderLayer in nn.TransformerEncoder
    dropout=0.2)

# %%
X_train = torch.Tensor(X_train)
y_train = torch.Tensor(y_train).float()

X_dev = torch.Tensor(X_dev)
y_dev = torch.Tensor(y_dev).float()

# %%
train_dataset = TensorDataset(X_train, y_train)
train_dataloader = DataLoader(train_dataset, batch_size=3)

dev_dataset = TensorDataset(X_dev, y_dev)
dev_dataloader = DataLoader(dev_dataset, batch_size=3) # create your dataloader

# %%
EPOCHS = 50
LR = 1e-4
CHECKPOINT = 'transformer.pt'

# %%
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
best_dev_loss = 10e18
best_dev_epoch = 1

for epoch in range(EPOCHS):  # loop over the dataset multiple times

    ############## Train
    model.train()
    tr_loss = 0.0
    t = tqdm(enumerate(train_dataloader, 0), desc='Progress')
    for i, data in t:
        t.set_postfix({
            'Epoch': epoch + 1,
            'Batch': i + 1, 
            'Train loss': tr_loss / (i + 1)
        })
    
        inputs, labels = data
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs.flatten(), labels)
        
        loss.backward()
        optimizer.step()

        tr_loss += loss.item()
    ############## Validation
    model.eval()
    dev_loss = 0.0
    t = tqdm(enumerate(dev_dataloader, 0), desc='Progress')
    for i, data in t:
        t.set_postfix({
            'Epoch': epoch + 1,
            'Batch': i + 1, 
            'Dev loss': dev_loss / (i + 1)
        })
    
        inputs, labels = data
        
        with torch.no_grad():
            outputs = model(inputs)
            loss = criterion(outputs.flatten(), labels)
            dev_loss += loss.item()
            
    if dev_loss < best_dev_loss:
        best_dev_epoch = epoch
        best_dev_loss = dev_loss
        torch.save(model.state_dict(), CHECKPOINT)
        
print('Finished Training. Best dev loss: {}. Epoch: {}.'.format(best_dev_loss / (len(dev_dataloader)), best_dev_epoch))
# Out:
# ...
# Finished Training. Best dev loss: 0.4541138971765195. Epoch: 28.

# %%
model.load_state_dict(torch.load(CHECKPOINT))
# Out:
# <All keys matched successfully>

# %%
model.eval()

with torch.no_grad():
    # Train
    y_train_pred = np.round(model(X_train))
    train_cm = confusion_matrix(y_train, y_train_pred)
    train_acc = accuracy_score(y_train, y_train_pred)
    
    # Validation
    y_dev_pred = np.round(model(X_dev))
    dev_cm = confusion_matrix(y_dev, y_dev_pred)
    dev_acc = accuracy_score(y_dev, y_dev_pred)

# %%
train_cm, train_acc
# Out:
# (array([[ 56,  78],
#         [  6, 289]]),
#  0.8041958041958042)

# %%
dev_cm, dev_acc
# Out:
# (array([[ 27,  31],
#         [  3, 124]]),
#  0.8162162162162162)

# %% [markdown]
# ## Attention analysis

# %%
model.eval()
# Out:
# TransformerModel(
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=64, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=64, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (embedding): Embedding(42, 40)
#   (num_embedding): Linear(in_features=1, out_features=40, bias=True)
#   (decoder): Linear(in_features=440, out_features=1, bias=True)
#   (activation): Sigmoid()
# )

# %% [markdown]
# Sampling 1 example from each one of next case:
#
# - Ground truth 0 but labeld as 0
# - Ground truth 1 but labeld as 1
# - Ground truth 0 but labeld as 1
# - Ground truth 1 but labeld as 0

# %%
y_dev_pred = y_dev_pred.cpu().detach().numpy().flatten()

# %%
# GT=0, Pred=0
indices_00 = np.intersect1d(np.where(y_dev == 0), np.where(y_dev_pred == 0))
# GT=1, Pred=1
indices_11 = np.intersect1d(np.where(y_dev == 1), np.where(y_dev_pred == 1))
# GT=0, Pred=1
indices_01 = np.intersect1d(np.where(y_dev == 0), np.where(y_dev_pred == 1))
# GT=1, Pred=0
indices_10 = np.intersect1d(np.where(y_dev == 1), np.where(y_dev_pred == 0))

# %%
SAMPLES_PER_CATEGORY = 2

# %%
indices = np.concatenate((
    np.random.choice(indices_00, SAMPLES_PER_CATEGORY),
    np.random.choice(indices_10, SAMPLES_PER_CATEGORY),
    np.random.choice(indices_11, SAMPLES_PER_CATEGORY),
    np.random.choice(indices_01, SAMPLES_PER_CATEGORY)
))

# %%
X_analysis = X_dev[indices]
y_analysis = y_dev[indices]
y_analysis_pred = y_dev_pred[indices]

# %%
src_cat = model.embedding(X_analysis[:, :len(categorical_cols)].squeeze().long())
src_num = model.num_embedding(X_analysis[:, len(categorical_cols):])
src_emb = torch.cat((src_cat, src_num), 1)

# %% [markdown]
# ### Correctness test

# %%
with torch.no_grad():
    
    # Computing X embeddings
    src = src_emb.transpose(0, 1)
    
    
    # Automatic self attention mechanism
    # Query, Key, Value
    attn_output_, attn_output_weights_ = model.transformer_encoder.layers[0].self_attn(src, src, src)
    
    
    # Manual self attention mechanism
    in_proj_weight = model.state_dict()['transformer_encoder.layers.0.self_attn.in_proj_weight']
    in_proj_bias = model.state_dict()['transformer_encoder.layers.0.self_attn.in_proj_bias']
    
    out_proj_weight = model.state_dict()['transformer_encoder.layers.0.self_attn.out_proj.weight']
    out_proj_bias = model.state_dict()['transformer_encoder.layers.0.self_attn.out_proj.bias']
    
    num_heads = 4
    tgt_len, bsz, embed_dim = src.size()
    head_dim = embed_dim // num_heads # embed_dim // num_heads
    scaling = float(head_dim) ** -0.5
    q, k, v = F.linear(src, 
                     in_proj_weight, 
                     in_proj_bias
                    ).chunk(3, dim=-1)
    
    q = q * scaling
    
    q = q.contiguous().view(tgt_len, bsz * num_heads, head_dim).transpose(0, 1)
    k = k.contiguous().view(-1, bsz * num_heads, head_dim).transpose(0, 1)
    v = v.contiguous().view(-1, bsz * num_heads, head_dim).transpose(0, 1)
    
    src_len = k.size(1)
    
    attn_output_weights = torch.bmm(q, k.transpose(1, 2))
    attn_output_weights = F.softmax(attn_output_weights, dim=-1)
    
    
    attn_output = torch.bmm(attn_output_weights, v)
    attn_output = attn_output.transpose(0, 1).contiguous().view(tgt_len, bsz, embed_dim)
    
    attn_output = F.linear(attn_output, out_proj_weight, out_proj_bias)
    
    attn_output_weights = attn_output_weights.view(bsz, num_heads, tgt_len, src_len)
    print(attn_output_weights.size())
    
assert torch.all(attn_output_.eq(attn_output))
assert torch.all(attn_output_weights_.eq(attn_output_weights.sum(dim=1) / num_heads))
# Out:
# torch.Size([8, 4, 11, 11])

# %% [markdown]
# ### Attention extraction

# %%
def plot_figs(data, row_titles=np.array([]), col_titles=np.array([])):
    n_rows = data.shape[0]
    n_columns = data.shape[1]
    n_features = data.shape[2]
    
    fig, big_axes = plt.subplots( figsize=(15.0, 6 * n_rows), nrows=n_rows, ncols=1, sharey=True) 

    for row, big_ax in enumerate(big_axes):
        if row_titles.shape == (n_rows,):
            big_ax.set_title(row_titles[row], fontsize=16)
        
        big_ax.tick_params(labelcolor=(1.,1.,1., 0.0), top=False, bottom=False, left=False, right=False)
        big_ax._frameon = False
    
    for i in range(0, n_rows * n_columns):
        ax = fig.add_subplot(n_rows, n_columns, i + 1)
        im = ax.imshow(data[i // n_columns, i % n_columns])
        
        #cbar.ax.set_ylabel('Probability', rotation=-90, va='top')
        
        # We want to show all ticks...
        ax.set_xticks(np.arange(n_features))
        ax.set_yticks(np.arange(n_features))
        # ... and label them with the respective list entries
        ax.set_xticklabels(np.arange(n_features))
        ax.set_yticklabels(np.arange(n_features))
        
        plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')
        
        if col_titles.shape == (n_rows, n_columns):
            ax.set_title(col_titles[i // n_columns, i % n_columns])
        
        #ax.set_title('Plot title ' + str(i))
    
    for row, big_ax in enumerate(big_axes):
        cbar = big_ax.figure.colorbar(im, ax=big_ax, orientation='horizontal')
        
    
    fig.set_facecolor('w')
    #fig.tight_layout()

# %%
# Attention weights
attn_weights = attn_output_weights.cpu().detach().numpy()
attn_weights_avg = attn_weights.sum(axis=1, keepdims=True) / num_heads

# %%
col_titles = []
row_titles = []

for row in range(attn_weights.shape[0]):
    row_titles.append('Example {}. Predicted {}. True {}.'.format(row, y_analysis_pred[row], y_analysis[row]))
    title_row = []
    for head in range(attn_weights.shape[1]):
        title_row.append(
            'Attention head {}.'.format(head + 1))
    
    title_row.append(
            'Attention head average.'.format(head))
    
    col_titles.append(title_row)
    
col_titles = np.array(col_titles)
row_titles = np.array(row_titles)

# %%
plot_figs(
    np.concatenate((
        attn_weights,
        attn_weights_avg
    ), axis=1), row_titles=row_titles, col_titles=col_titles)

# %%
plot_figs(
    np.concatenate((
        (attn_weights > 0.17).astype(int),
        (attn_weights_avg  > 0.17).astype(int)
    ), axis=1), row_titles=row_titles, col_titles=col_titles)
